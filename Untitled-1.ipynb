# %%
import pandas as pd
import requests
import seaborn as sns

# %%
url_imf = "http://dataservices.imf.org/REST/SDMX_JSON.svc/"
key = "CompactData/IFS/M.VN.TXG_FOB_USD"
data = requests.get(f"{url_imf}{key}", timeout=500).json()[
    "CompactData"
]["DataSet"]["Series"]

# %%
data
# Out:
# {'@FREQ': 'M',
#  '@REF_AREA': 'VN',
#  '@INDICATOR': 'TXG_FOB_USD',
#  '@UNIT_MULT': '6',
#  '@TIME_FORMAT': 'P1M',
#  'Obs': [{'@TIME_PERIOD': '2006-01', '@OBS_VALUE': '3064'},
#   {'@TIME_PERIOD': '2006-02', '@OBS_VALUE': '2416'},
#   {'@TIME_PERIOD': '2006-03', '@OBS_VALUE': '3427'},
#   {'@TIME_PERIOD': '2006-04', '@OBS_VALUE': '3006'},
#   {'@TIME_PERIOD': '2006-05', '@OBS_VALUE': '3407'},
#   {'@TIME_PERIOD': '2006-06', '@OBS_VALUE': '3509'},
#   {'@TIME_PERIOD': '2006-07', '@OBS_VALUE': '3595'},
#   {'@TIME_PERIOD': '2006-08', '@OBS_VALUE': '3754'},
#   {'@TIME_PERIOD': '2006-09', '@OBS_VALUE': '3330'},
#   {'@TIME_PERIOD': '2006-10', '@OBS_VALUE': '3411'},
#   {'@TIME_PERIOD': '2006-11', '@OBS_VALUE': '3431'},
#   {'@TIME_PERIOD': '2006-12', '@OBS_VALUE': '3478'},
#   {'@TIME_PERIOD': '2007-01', '@OBS_VALUE': '3836'},
#   {'@TIME_PERIOD': '2007-02', '@OBS_VALUE': '2906'},
#   {'@TIME_PERIOD': '2007-03', '@OBS_VALUE': '3872'},
# ...
