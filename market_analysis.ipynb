# %%
from function import *

with open(path_dictionary, "r") as a:
    name_dict = json.load(a)

# %%
stock_data = clean_daily_data(path_stock_data, path_ticker, name_dict)

# %%
market = (
    stock_data.groupby(["exchange", "time"])[
        [
            "return_weighted",
            "log_return_weighted",
        ]
    ]
    .sum()
    .reset_index()
)

# %% [markdown]
# ## winsorize the outliner

# %%
market_winsored = pd.DataFrame()
for i in market["exchange"].unique():
    temp = market.loc[market["exchange"] == i]
    temp["return_weighted"] = winsorize(
        temp["return_weighted"], limits=[0.05, 0.05]
    )
    temp["log_return_weighted"] = winsorize(
        temp["log_return_weighted"], limits=[0.05, 0.05]
    )
    market_winsored = pd.concat([market_winsored, temp], axis=0)
    # Detect outliers using Z-score

# %% [markdown]
# # test stationary

# %%
for i in market["exchange"].unique():
    temp = market[market["exchange"] == i]["return_weighted"]
    returns = winsorize(temp, limits=[0.05, 0.05])
    print(i)
    adf_test(temp, 0.01)
    kpss_test(temp, 0.01)
# Out:
# DELISTED
# ADF Test Results:
# ADF Statistic: -5.6653246373946455
# p-value: 9.179898357429256e-07
# Critical Value (1%): -3.4325853286163874
# Critical Value (5%): -2.8625276197775373
# Critical Value (10%): -2.5672957374856296
# Judgment: The series is likely stationary (Reject null hypothesis).
#
# ========================================
#
# KPSS Test Results:
# KPSS Statistic: 0.6065963107295933
# p-value: 0.022036699024582426
# Critical Value (10%): 0.347
# Critical Value (5%): 0.463
# Critical Value (2.5%): 0.574
# Critical Value (1%): 0.739
# Judgment: The series is likely stationary (Fail to reject null hypothesis).
#
# ========================================
#
# HNX
# ADF Test Results:
# ADF Statistic: -6.466298380247844
# p-value: 1.402538851500631e-08
# Critical Value (1%): -3.4325860929804404
# Critical Value (5%): -2.8625279573644873
# Critical Value (10%): -2.5672959172141048
# Judgment: The series is likely stationary (Reject null hypothesis).
#
# ========================================
#
# KPSS Test Results:
# KPSS Statistic: 2.4515047096145235
# p-value: 0.01
# Critical Value (10%): 0.347
# Critical Value (5%): 0.463
# Critical Value (2.5%): 0.574
# Critical Value (1%): 0.739
# Judgment: The series is likely stationary (Fail to reject null hypothesis).
#
# ========================================
#
# HSX
# ADF Test Results:
# ADF Statistic: -28.796512134941946
# p-value: 0.0
# Critical Value (1%): -3.43256789134622
# Critical Value (5%): -2.8625199184567043
# Critical Value (10%): -2.5672916373706265
# Judgment: The series is likely stationary (Reject null hypothesis).
#
# ========================================
#
# KPSS Test Results:
# KPSS Statistic: 1.1324529267581334
# p-value: 0.01
# Critical Value (10%): 0.347
# Critical Value (5%): 0.463
# Critical Value (2.5%): 0.574
# Critical Value (1%): 0.739
# Judgment: The series is likely stationary (Fail to reject null hypothesis).
#
# ========================================
#
# UPCOM
# ADF Test Results:
# ADF Statistic: -8.850500153939329
# p-value: 1.577723190811983e-14
# Critical Value (1%): -3.4325799926649294
# Critical Value (5%): -2.8625252631133096
# Critical Value (10%): -2.567294482817665
# Judgment: The series is likely stationary (Reject null hypothesis).
#
# ========================================
#
# KPSS Test Results:
# KPSS Statistic: 3.9379936620096117
# p-value: 0.01
# Critical Value (10%): 0.347
# Critical Value (5%): 0.463
# Critical Value (2.5%): 0.574
# Critical Value (1%): 0.739
# Judgment: The series is likely stationary (Fail to reject null hypothesis).
#
# ========================================

# %% [markdown]
# # Seasonarity

# %% [markdown]
# * with the cycle is 2 year: the trend is more observable

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

for i in market["exchange"].unique():
    temp = market[market["exchange"] == i]["return_weighted"]
    i
    result = seasonal_decompose(temp, model="additive", period=1000)
    result.plot()
    plt.close()
# Out:
# 'DELISTED'
# 'HNX'
# 'HSX'
# 'UPCOM'

# %% [markdown]
# * With 1 year cycle: the trend might not be so clear

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

for i in market["exchange"].unique():
    temp = market[market["exchange"] == i]["return_weighted"]
    i
    result = seasonal_decompose(temp, model="additive", period=500)
    result.plot()
    plt.close()
# Out:
# 'DELISTED'
# 'HNX'
# 'HSX'
# 'UPCOM'

# %%
windows = [10, 30, 70, 120, 200]  # number of trading dates
for i in market["exchange"].unique():
    if i == "HSX":
        temp = market[market["exchange"] == i]
        print(i)
        draw_SMA(temp, "return_weighted", windows)
        draw_EMA(temp, "return_weighted", windows)
        draw_cumulative(temp, "log_return_weighted", windows)
# Out:
# HSX

# %% [markdown]
# # Visualize with AR and ARIMA regression

# %%
df = real_time_AR_visualize(
    market[market["exchange"] == "HSX"],
    "return_weighted",
    "time",
    252,
    30,
)

# %%
df = real_time_ARIMA_visualize(
    market[market["exchange"] == "HSX"],
    "return_weighted",
    "time",
    252,
    [2, 0, 2],
    # para=True,
)
