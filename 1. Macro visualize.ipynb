# %%
from macro import *
from bao import *  # type: ignore
from static import *

# %%
# update macro data: currently including country: CPI, EX-IM, Interest rate, and exchange rate
macro_data = MacroData("./data/macro/", "./macro.json")
# macro_data.create_or_update_all()

# %% [markdown]
# ## Visualize

# %%
macro_data.visualize_macro()
# Out:
# There is no country data for VN in GOV_BOND
# There is no country data for VN in UNEMPLOYMENT_RATE

# %%
macro_data.visualize_macro("GB")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 macro_data.visualize_macro("GB")
#
# File /mmt/local/stock_quant/macro.py:278, in MacroData.visualize_macro(self, country_name)
#     276 # 3. Plot Each Indicator
#     277 for i, indicator in enumerate(df_names):
# --> 278     ax = axes[i]
#     279     sns.lineplot(
#     280         data=combined_df[
#     281             combined_df["Indicator"] == indicator
#    (...)
#     286         label=indicator,
#     287     )
#     288     ax.set_title(indicator)
#
# IndexError: index 8 is out of bounds for axis 0 with size 8
# Error in callback <function flush_figures at 0x7f0355738a40> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ...

# %%
GB_data, na = macro_data.read_data_only("GB")

# %%
combined_df = pd.concat(
    [df.assign(Indicator=name) for df, name in zip(GB_data, na)]
)

# %%
_, axes = plt.subplots(nrows=4, ncols=2, figsize=(15, 12))
axes = axes.flatten()

# %%
VN_data = macro_data.read_data_only("VN")
